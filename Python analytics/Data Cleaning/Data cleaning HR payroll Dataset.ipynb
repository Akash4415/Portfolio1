# %% [markdown]
# <span style="font-family: Arial; font-size: 25px; font-weight: bold;">
# Import Packages
# </span>

# %%
import pandas as pd
import numpy as np
# !pip install pandas openpyxl
from dateutil.relativedelta import relativedelta
# Out:
# Requirement already satisfied: pandas in d:\python\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in d:\python\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in d:\python\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\python\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\python\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\python\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: et-xmlfile in d:\python\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in d:\python\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# <span style="font-family: Arial; font-size: 25px; font-weight: bold;">
# Loading the Dataset
# </span>

# %%
df = pd.read_csv("HR payroll Dataset.csv") # replace with your actual file name

# %% [markdown]
# <span style="font-family: Arial; font-size: 25px; font-weight: bold;">
# Remove Duplicate Employee IDs</span>

# %%
df = df.drop_duplicates(subset='EmployeeID', keep='first')

# %% [markdown]
# <span style="font-family: Arial; font-size: 25px; font-weight: bold;">
# Convert Salary from Text to Numeric</span>

# %%
df['Salary'] = (
    df['Salary']
    .astype(str)
    .str.replace(r'[^0-9.]', '', regex=True)
    .replace('', np.nan)
    .astype(float)
)

# %% [markdown]
# <span style="font-family: Arial; font-size: 25px; font-weight: bold;">
# Standardize Department Names</span>

# %%
department_mapping = {
    'Mktg': 'Marketing',
    'Marketing': 'Marketing',
    'Sale': 'Sales',
    'Sales': 'Sales',
    'Engg': 'Engineering',
    'Engineering': 'Engineering',
    'HR': 'Human Resources',
    'Human Resource': 'Human Resources',
    'Ops': 'Operations',
    'Operations': 'Operations',
    'Info Tech' : 'IT',
    'IT': 'IT',
    'Fin.': 'Finance',
    'Finance': 'Finance'
}

df['Department'] = (
    df['Department']
    .str.strip()
    .replace(department_mapping)
)

# %%
df['JoiningDate'] = pd.to_datetime(
    df['JoiningDate'],
    dayfirst=True,
    errors='coerce'
)

df['LastWorkingDate'] = pd.to_datetime(
    df['LastWorkingDate'],
    dayfirst=True,
    errors='coerce'
)

# %%
median_joining_date = df['JoiningDate'].median()
df['JoiningDate'] = df['JoiningDate'].fillna(median_joining_date)

# %% [markdown]
# <span style="font-family: Arial; font-size: 25px; font-weight: bold;">
# Create Tenure Column for Active Empployees</span>

# %%
today = pd.Timestamp.today().normalize()

def calculate_tenure(row):
    if pd.isna(row['LastWorkingDate']):  # Active employee
        rd = relativedelta(today, row['JoiningDate'])
        return f"{rd.years} years {rd.months} months {rd.days} days"
    else:
        return None  # Not required for inactive employees

df['Active_Employee_Tenure'] = df.apply(calculate_tenure, axis=1)

# %%
df[['JoiningDate', 'LastWorkingDate', 'Active_Employee_Tenure']].head()
# Out:
#   JoiningDate LastWorkingDate     Active_Employee_Tenure
# 0  2019-05-28             NaT   6 years 6 months 16 days
# 1  2020-06-08             NaT    5 years 6 months 6 days
# 2  2015-10-07      2016-10-18                       None
# 3  2014-10-01             NaT  11 years 2 months 13 days
# 4  2020-08-10             NaT    5 years 4 months 4 days

# %%
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47728 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   EmployeeID              47728 non-null  int64
#  1   FullName                47728 non-null  object
#  2   FirstName               47728 non-null  object
#  3   LastName                47728 non-null  object
#  4   Age                     47728 non-null  int64
#  5   Gender                  47728 non-null  object
#  6   JobTitle                47728 non-null  object
#  7   Department              47728 non-null  object
#  8   Location                47728 non-null  object
#  9   EmploymentType          47728 non-null  object
#  10  Salary                  47728 non-null  float64
#  11  JoiningDate             47728 non-null  datetime64[ns]
#  12  LastWorkingDate         11986 non-null  datetime64[ns]
#  13  Active_Employee_Tenure  35742 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 5.5+ MB
# None
#    EmployeeID         FullName FirstName LastName  Age  Gender  \
# 0       50171    Charles Brown   Charles    Brown   59  Female
# 1       41653      Mary Wilson      Mary   Wilson   39  Female
# 2       36344      Karen Lopez     Karen    Lopez   37  Female
# 3       42517  William Jackson   William  Jackson   57    Male
# 4       36594    William Jones   William    Jones   51  Female
#
#              JobTitle       Department       Location EmploymentType  \
# 0  Operations Manager        Marketing         Boston      Full-time
# 1          Accountant            Sales    Los Angeles      Full-time
# 2          HR Manager  Human Resources  San Francisco      Part-time
# 3  Operations Manager      Engineering        Atlanta      Full-time
# 4  Operations Manager        Marketing  San Francisco      Full-time
#
#      Salary JoiningDate LastWorkingDate     Active_Employee_Tenure
# 0  108690.0  2019-05-28             NaT   6 years 6 months 16 days
# 1   53895.0  2020-06-08             NaT    5 years 6 months 6 days
# 2  122552.0  2015-10-07      2016-10-18                       None
# 3  125701.0  2014-10-01             NaT  11 years 2 months 13 days
# 4  124473.0  2020-08-10             NaT    5 years 4 months 4 days

# %%
df['JoiningDate'] = pd.to_datetime(df['JoiningDate'], dayfirst=True, errors='coerce').dt.strftime('%Y-%m-%d')
df['LastWorkingDate'] = pd.to_datetime(df['LastWorkingDate'], dayfirst=True, errors='coerce').dt.strftime('%Y-%m-%d')

# %%
# Export cleaned dataframe to CSV
df.to_csv(
    "HR_Payroll_data_v1.csv",
    index=False,
    encoding="utf-8"
)

# %%
print("Cleaned data successfully exported to HR_Payroll_data_v1")
# Out:
# Cleaned data successfully exported to HR_Payroll_data_v1
